# %% [markdown]
# # Cfg de Git
#
# Configuro la identidad del usuario para registrar de manera correcta los commits hechos en el repositorio.

# %%
# !git config --global user.email "faugustobp@gmail.com"
# !git config --global user.name "Francisco Barandiarán"

# %% [markdown]
# # Clonación del repositorio
#
# Se clona el repositorio remoto desde GitHub para trabajar sobre el proyecto en Collab.

# %%
# !git clone https://github.com/setox0p/TP-Gesti-n-Colaborativa-Ventas-.git
# Out:
# Cloning into 'TP-Gesti-n-Colaborativa-Ventas-'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 32 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 10.80 KiB | 10.80 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %% [markdown]
# # Ejecución del análisis de ventas
#
# Se ejecuta el script principal del proyecto para procesar el dataset y generar resultados.

# %%
# %cd TP-Gesti-n-Colaborativa-Ventas-
# Out:
# /content/TP-Gesti-n-Colaborativa-Ventas-

# %%
# !pip install pandas matplotlib

# %%
# !python scripts/analisis_ventas.py
# Out:
# datos cargados:
#    id     producto  cantidad  precio       fecha
# 0   1      Teclado         2   15000  2026-05-10
# 1   2        Mouse         5    8000  2026-05-11
# 2   3      Monitor         1  120000  2026-05-12
# 3   4      Teclado         3   15000  2026-05-13
# 4   5  Auriculares         4   12000  2026-05-14
#
# Ventas totales:
# 283000
#
# Producto más vendido:
# Mouse
#
# Grafico generado correctamente.

# %% [markdown]
# # Visualización de resultados
#
# Se muestra el gráfico generado automáticamente por el script de análisis.

# %%
from IPython.display import Image
Image("resultados/grafico_ventas.png")
